# %%
import pandas as pd
import numpy as np

# %%
float_data = pd.Series([1.2,-3.4,np.nan,5])
float_data
# Out:
# 0    1.2
# 1   -3.4
# 2    NaN
# 3    5.0
# dtype: float64

# %%
float_data.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
float_data[~float_data.isna()]
# Out:
# 0    1.2
# 1   -3.4
# 3    5.0
# dtype: float64

# %%
float_data[float_data.notna()]
# Out:
# 0    1.2
# 1   -3.4
# 3    5.0
# dtype: float64

# %%
data = pd.DataFrame([[1,5.6,3], # each list is a separate row
                     [1.,np.nan,np.nan],
                     [np.nan,np.nan,np.nan],
                     [np.nan,3.5,3.]],
                   columns=['a','b','c'])

# %%
data
# Out:
#      a    b    c
# 0  1.0  5.6  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  3.5  3.0

# %%
data1 = pd.DataFrame({'a':[1,1,np.nan,np.nan],
                      'b':[5.6,np.nan,np.nan,3.5],
                      'c':[3,np.nan,np.nan,3]})

# %%
data1
# Out:
#      a    b    c
# 0  1.0  5.6  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  3.5  3.0

# %%
print(data1.dropna()) # by default it is how = any
print(data1.dropna(how= 'any'))
# Out:
#      a    b    c
# 0  1.0  5.6  3.0
#      a    b    c
# 0  1.0  5.6  3.0

# %%
data1.dropna(how='all') # how ='all' means all the values of a row should be null then only it will get dropped
# Out:
#      a    b    c
# 0  1.0  5.6  3.0
# 1  1.0  NaN  NaN
# 3  NaN  3.5  3.0

# %%
data.dropna(axis=True,how='all') # be default the axis is row that the values is 0, False
# Out:
#      a    b    c
# 0  1.0  5.6  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  3.5  3.0

# %%
df = pd.DataFrame(np.random.standard_normal((7,3)))
df
# Out:
#           0         1         2
# 0 -0.432698  1.502212 -1.197421
# 1 -3.099905 -0.310957 -0.561378
# 2  0.227361 -1.797763 -2.161525
# 3 -1.648474  1.997603 -1.750501
# 4 -0.241063 -0.763577  1.111396
# 5 -1.139065 -0.608434 -1.529794
# 6 -1.640502  0.205644 -1.380876

# %%
df.iloc[:4,1]=np.nan
df.iloc[:2,2]=np.nan
df
# Out:
#           0         1         2
# 0 -0.432698       NaN       NaN
# 1 -3.099905       NaN       NaN
# 2  0.227361       NaN -2.161525
# 3 -1.648474       NaN -1.750501
# 4 -0.241063 -0.763577  1.111396
# 5 -1.139065 -0.608434 -1.529794
# 6 -1.640502  0.205644 -1.380876

# %%
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2  0.227361       NaN -2.161525
# 3 -1.648474       NaN -1.750501
# 4 -0.241063 -0.763577  1.111396
# 5 -1.139065 -0.608434 -1.529794
# 6 -1.640502  0.205644 -1.380876

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0 -0.432698  0.000000  0.000000
# 1 -3.099905  0.000000  0.000000
# 2  0.227361  0.000000 -2.161525
# 3 -1.648474  0.000000 -1.750501
# 4 -0.241063 -0.763577  1.111396
# 5 -1.139065 -0.608434 -1.529794
# 6 -1.640502  0.205644 -1.380876

# %%
df.fillna({1:0,2:2})
# Out:
#           0         1         2
# 0 -0.432698  0.000000  2.000000
# 1 -3.099905  0.000000  2.000000
# 2  0.227361  0.000000 -2.161525
# 3 -1.648474  0.000000 -1.750501
# 4 -0.241063 -0.763577  1.111396
# 5 -1.139065 -0.608434 -1.529794
# 6 -1.640502  0.205644 -1.380876

# %%
df = pd.DataFrame(np.random.standard_normal((6,3)))

df.iloc[2:,1]=np.nan
df.iloc[4:,2]=np.nan
df
# Out:
#           0         1         2
# 0  1.170973 -0.877610 -0.255740
# 1 -0.958684 -0.361728 -1.156715
# 2  1.374910       NaN -0.621841
# 3  1.608864       NaN -0.136871
# 4  1.077966       NaN       NaN
# 5 -0.461113       NaN       NaN

# %%
df.ffill()# fillna(method = ffill) is deprecated and ffill funtion is created
# Out:
#           0         1         2
# 0  1.170973 -0.877610 -0.255740
# 1 -0.958684 -0.361728 -1.156715
# 2  1.374910 -0.361728 -0.621841
# 3  1.608864 -0.361728 -0.136871
# 4  1.077966 -0.361728 -0.136871
# 5 -0.461113 -0.361728 -0.136871

# %%
df.ffill(axis=1,limit=1)
# Out:
#           0         1         2
# 0  1.170973 -0.877610 -0.255740
# 1 -0.958684 -0.361728 -1.156715
# 2  1.374910  1.374910 -0.621841
# 3  1.608864  1.608864 -0.136871
# 4  1.077966  1.077966       NaN
# 5 -0.461113 -0.461113       NaN

# %% [markdown]
# ## 7.2 Data Transformation

# %% [markdown]
# ## Removing Duplicates

# %%
data= pd.DataFrame({'k1':['one',"two"]*3+['two'],
                    'k2':[1,1,2,3,3,4,4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data[data.duplicated(subset=['k1'],keep='last')] # last will be the 1st occurence
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 5  two   4

# %%
data.drop_duplicates(subset=['k1'],
                     keep='first',
                     ignore_index=True)
# Out:
#     k1  k2
# 0  one   1
# 1  two   1

# %%
data['v1']=range(7)
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(subset=['k1'],
                    keep='last')
# Out:
#     k1  k2  v1
# 4  one   3   4
# 6  two   4   6

# %%
data = pd.DataFrame({"food": ["bacon", "pulled pork", "bacon",
                              "pastrami", "corned beef", "bacon",
                              "pastrami", "honey ham", "nova lox"],
                     "ounces": [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %% [markdown]
# ## Transforming Data Using a Function or Mapping

# %%
meat_to_animal={
    'bacon':'pig',
    'pulled pork':'pig',
    'pastrami':'cow',
    'corned beef':'cow',
    'honey ham':'pig',
    'nova lox': 'salmon'
}

# %%
data['animal'] = data['food'].map(meat_to_animal)

# %%
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon
